# %%
from distributions import build_distributions_df
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\Brave\anaconda3\envs\PythonData38\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\Brave\anaconda3\envs\PythonData38\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Brave\anaconda3\envs\PythonData38\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\Brave\anaconda3\envs\PythonData38\lib\http\client.py", line 1348, in getresponse
#     response.begin()
#   File "C:\Users\Brave\anaconda3\envs\PythonData38\lib\http\client.py", line 316, in begin
#     version, status, reason = self._read_status()
# ...
